# %%
#############################################################################
# Load Required Libraries
#############################################################################
suppressPackageStartupMessages({
  library(infercnv)
  library(dplyr)
  library(purrr)
  library(tidyr)
  library(readr)
})

# %% [markdown]
# # Helper Functions

# %%
# 1) Function to read a single partial run’s outputs
read_infercnv_run <- function(run_dir) {
  # Each partial run directory should contain the key files:
  #   - final infercnv object (RDS)
  #   - predicted CNV regions (HMM_CNV_predictions...pred_cnv_regions.dat)
  #   - predicted CNV genes (HMM_CNV_predictions...pred_cnv_genes.dat)
  #   - Possibly MCMC/BayesNet results if needed

  # Adjust filenames as per your actual naming scheme:
  final_obj_file    <- file.path(run_dir, "run.final.infercnv_obj")
  region_file       <- file.path(run_dir, "HMM_CNV_predictions.HMMi6.hmm_mode-samples.Pnorm_0.5.pred_cnv_regions.dat")
  genes_file        <- file.path(run_dir, "HMM_CNV_predictions.HMMi6.hmm_mode-samples.Pnorm_0.5.pred_cnv_genes.dat")
  
  out <- list()
  
  # Load the final infercnv_obj (if available)
  if (file.exists(final_obj_file)) {
    out$infercnv_obj <- readRDS(final_obj_file)
  } else {
    warning("No final infercnv_obj found in: ", final_obj_file)
  }
  
  # Load region calls
  if (file.exists(region_file)) {
    out$pred_regions <- read.table(region_file, sep = "\t", header = TRUE, stringsAsFactors = FALSE)
  } else {
    warning("No region file found in: ", region_file)
  }
  
  # Load gene calls
  if (file.exists(genes_file)) {
    out$pred_genes <- read.table(genes_file, sep = "\t", header = TRUE, stringsAsFactors = FALSE)
  } else {
    warning("No gene file found in: ", genes_file)
  }
  
  return(out)
}

# %%
dirs_er_list <- list("/home/igarzonalva/Proyecto_SC_TNBC/GSE161529/InferCNV/split_1/", 
                "/home/igarzonalva/Proyecto_SC_TNBC/GSE161529/InferCNV/split_2/",
                "/home/igarzonalva/Proyecto_SC_TNBC/GSE161529/InferCNV/split_3/")

# %%
data_er <- lapply(dirs_er_list, read_infercnv_run)

# %%
# 2) Function to merge partial runs for a single sample
#    - Merges expression data (if feasible) and CNV call tables
merge_partial_runs <- function(run_list, exp = FALSE) {
  
  # ---- Expression data (merge if each partial run used the same gene ordering) ----
  # This step can be memory-intensive if the dataset is large.
  # Only attempt if you truly need a single large expression matrix.
  # Otherwise, skip merging expression data and just focus on CNV calls.

    if (exp == TRUE){
      # Example merging expression data from final infercnv_obj in each run:
      expr_list <- lapply(run_list, function(x) {
        if (!is.null(x$infercnv_obj)) {
          return(x$infercnv_obj@expr.data)
        } else {
          return(NULL)
        }
      })
      # Filter out NULL elements
      expr_list <- expr_list[!sapply(expr_list, is.null)]
      
      # Confirm same row ordering (genes) for each partial expression matrix
      # If all row orders match, we can cbind them
      # Otherwise, you may need more complex alignment by gene ID
      merged_expr <- NULL
      if (length(expr_list) > 1) {
        # Check if all have identical rownames
        common_genes <- Reduce(intersect, lapply(expr_list, rownames))
        if (length(common_genes) > 0) {
          # Subset each matrix to common genes, then combine columns
          expr_list_aligned <- lapply(expr_list, function(m) m[common_genes, , drop=FALSE])
          merged_expr <- do.call(cbind, expr_list_aligned)
        } else {
          warning("No common genes found among partial runs! Skipping expression merge.")
        }
      } else if (length(expr_list) == 1) {
        merged_expr <- expr_list[[1]]
      }
                                      
    }
  
  # ---- Region calls ----
  # Combine region calls from all partial runs (rows)
  region_tables <- lapply(run_list, function(x) x$pred_regions)
  region_tables <- region_tables[!sapply(region_tables, is.null)]
  
  merged_regions <- bind_rows(region_tables, .id = "partial_run_id")
  # partial_run_id indicates which partial run each row came from
  
  # ---- Gene calls ----
  gene_tables <- lapply(run_list, function(x) x$pred_genes)
  gene_tables <- gene_tables[!sapply(gene_tables, is.null)]
  
  merged_genes <- bind_rows(gene_tables, .id = "partial_run_id")

                        
  # Return a list of merged data
  if (exp == TRUE){
    merged_out <- list(
        merged_expr    = merged_expr,
        merged_regions = merged_regions,
        merged_genes   = merged_genes
      )
      
      return(merged_out)
      }
    else {
        merged_out <- list(
        merged_regions = merged_regions,
        merged_genes   = merged_genes
      )
        }
        
}

# %%
merged_er <- merge_partial_runs(data_er)

# %%
merged_er
# Out:
# $merged_regions
#     partial_run_id                        cell_group_name      cnv_name state
# 1                1               Epithelial.Epithelial_s1    1-region_2     2
# 2                1               Epithelial.Epithelial_s1    1-region_4     4
# 3                1               Epithelial.Epithelial_s1    1-region_6     3
# 4                1               Epithelial.Epithelial_s1   6-region_12     2
# 5                1               Epithelial.Epithelial_s1   7-region_14     4
# 6                1               Epithelial.Epithelial_s1   8-region_17     3
# 7                1               Epithelial.Epithelial_s1   8-region_19     3
# 8                1               Epithelial.Epithelial_s1  11-region_21     3
# 9                1               Epithelial.Epithelial_s1  11-region_23     4
# 10               1               Epithelial.Epithelial_s1  11-region_25     2
# 11               1               Epithelial.Epithelial_s1  12-region_28     4
# 12               1               Epithelial.Epithelial_s1  12-region_30     2
# 13               1               Epithelial.Epithelial_s1  12-region_32     3
# 14               1               Epithelial.Epithelial_s1  13-region_33     1
# 15               1               Epithelial.Epithelial_s1  16-region_36     3
# 16               1               Epithelial.Epithelial_s1  16-region_38     2
# 17               1               Epithelial.Epithelial_s1  20-region_42     4
# 18               1               Epithelial.Epithelial_s1  19-region_43     3
# 19               1               Epithelial.Epithelial_s1  22-region_45     4
# 20               1               Epithelial.Epithelial_s1  21-region_47     4
# 21               1 CyclingEpithelial.CyclingEpithelial_s1   1-region_50     4
# 22               1 CyclingEpithelial.CyclingEpithelial_s1   1-region_52     3
# 23               1 CyclingEpithelial.CyclingEpithelial_s1   6-region_58     2
# 24               1 CyclingEpithelial.CyclingEpithelial_s1   7-region_60     4
# 25               1 CyclingEpithelial.CyclingEpithelial_s1   8-region_64     3
# 26               1 CyclingEpithelial.CyclingEpithelial_s1  11-region_67     4
# 27               1 CyclingEpithelial.CyclingEpithelial_s1  11-region_69     2
# 28               1 CyclingEpithelial.CyclingEpithelial_s1  12-region_71     3
# 29               1 CyclingEpithelial.CyclingEpithelial_s1  12-region_73     4
# 30               1 CyclingEpithelial.CyclingEpithelial_s1  12-region_74     4
# 31               1 CyclingEpithelial.CyclingEpithelial_s1  12-region_75     3
# 32               1 CyclingEpithelial.CyclingEpithelial_s1  12-region_77     4
# 33               1 CyclingEpithelial.CyclingEpithelial_s1  13-region_78     1
# 34               1 CyclingEpithelial.CyclingEpithelial_s1  14-region_80     4
# 35               1 CyclingEpithelial.CyclingEpithelial_s1  16-region_82     4
# 36               1 CyclingEpithelial.CyclingEpithelial_s1  16-region_84     2
# 37               1 CyclingEpithelial.CyclingEpithelial_s1  17-region_86     2
# 38               1 CyclingEpithelial.CyclingEpithelial_s1  20-region_89     4
# 39               1 CyclingEpithelial.CyclingEpithelial_s1  20-region_90     3
# 40               1 CyclingEpithelial.CyclingEpithelial_s1  19-region_91     3
# 41               1 CyclingEpithelial.CyclingEpithelial_s1  19-region_93     3
# 42               1 CyclingEpithelial.CyclingEpithelial_s1  22-region_95     4
# 43               1 CyclingEpithelial.CyclingEpithelial_s1  21-region_97     4
# 44               1 CyclingEpithelial.CyclingEpithelial_s1  MT-region_98     6
# 45               1                     Unknown.Unknown_s1  1-region_100     2
# 46               1                     Unknown.Unknown_s1  5-region_106     4
# 47               1                     Unknown.Unknown_s1  6-region_109     2
# 48               1                     Unknown.Unknown_s1  9-region_114     3
# 49               1                     Unknown.Unknown_s1 11-region_116     4
# 50               1                     Unknown.Unknown_s1 11-region_118     4
# 51               1                     Unknown.Unknown_s1 10-region_120     4
# 52               1                     Unknown.Unknown_s1 12-region_122     3
# 53               1                     Unknown.Unknown_s1 12-region_124     4
# 54               1                     Unknown.Unknown_s1 16-region_130     4
# 55               1                     Unknown.Unknown_s1 16-region_132     2
# 56               1                     Unknown.Unknown_s1 17-region_134     4
# 57               1                     Unknown.Unknown_s1 20-region_138     3
# 58               1                     Unknown.Unknown_s1 19-region_141     4
# 59               1                     Unknown.Unknown_s1 22-region_144     3
# 60               1                     Unknown.Unknown_s1 21-region_146     4
# 61               1                     Myeloid.Myeloid_s1  1-region_149     4
# 62               1                     Myeloid.Myeloid_s1  1-region_151     4
# 63               1                     Myeloid.Myeloid_s1  5-region_157     3
# 64               1                     Myeloid.Myeloid_s1  6-region_159     3
# 65               1                     Myeloid.Myeloid_s1  7-region_161     4
# 66               1                     Myeloid.Myeloid_s1  X-region_163     3
# 67               1                     Myeloid.Myeloid_s1  8-region_165     3
# 68               1                     Myeloid.Myeloid_s1 11-region_168     4
# 69               1                     Myeloid.Myeloid_s1 11-region_170     4
# 70               1                     Myeloid.Myeloid_s1 14-region_176     3
# 71               1                     Myeloid.Myeloid_s1 15-region_178     4
# 72               1                     Myeloid.Myeloid_s1 17-region_181     3
# 73               1                     Myeloid.Myeloid_s1 20-region_184     4
# 74               1                     Myeloid.Myeloid_s1 19-region_187     4
# 75               1                     Myeloid.Myeloid_s1 22-region_189     4
# 76               1                     Myeloid.Myeloid_s1 21-region_191     3
# 77               1                     Myeloid.Myeloid_s1 MT-region_192     1
# 78               1             Fibroblasts.Fibroblasts_s1  1-region_194     2
# 79               1             Fibroblasts.Fibroblasts_s1  1-region_196     3
# 80               1             Fibroblasts.Fibroblasts_s1  2-region_198     3
# 81               1             Fibroblasts.Fibroblasts_s1  2-region_200     2
# 82               1             Fibroblasts.Fibroblasts_s1  2-region_202     4
# 83               1             Fibroblasts.Fibroblasts_s1  4-region_206     4
# 84               1             Fibroblasts.Fibroblasts_s1  6-region_209     2
# 85               1             Fibroblasts.Fibroblasts_s1  7-region_212     4
# 86               1             Fibroblasts.Fibroblasts_s1 11-region_216     4
# 87               1             Fibroblasts.Fibroblasts_s1 11-region_218     4
# 88               1             Fibroblasts.Fibroblasts_s1 11-region_220     4
# 89               1             Fibroblasts.Fibroblasts_s1 12-region_224     3
# 90               1             Fibroblasts.Fibroblasts_s1 15-region_228     4
# 91               1             Fibroblasts.Fibroblasts_s1 16-region_231     2
# 92               1             Fibroblasts.Fibroblasts_s1 17-region_233     4
# 93               1             Fibroblasts.Fibroblasts_s1 20-region_236     4
# 94               1             Fibroblasts.Fibroblasts_s1 19-region_239     2
# 95               1             Fibroblasts.Fibroblasts_s1 22-region_240     4
# 96               1             Fibroblasts.Fibroblasts_s1 21-region_241     4
# 97               1             Fibroblasts.Fibroblasts_s1 21-region_242     5
# 98               1             Fibroblasts.Fibroblasts_s1 MT-region_243     1
# 99               1             Endothelial.Endothelial_s1  1-region_245     3
# 100              1             Endothelial.Endothelial_s1  3-region_249     4
# 101              1             Endothelial.Endothelial_s1  4-region_252     4
# 102              1             Endothelial.Endothelial_s1  6-region_256     3
# 103              1             Endothelial.Endothelial_s1  7-region_259     3
# 104              1             Endothelial.Endothelial_s1  8-region_262     3
# 105              1             Endothelial.Endothelial_s1  9-region_265     3
# 106              1             Endothelial.Endothelial_s1 11-region_266     4
# 107              1             Endothelial.Endothelial_s1 12-region_269     3
# 108              1             Endothelial.Endothelial_s1 14-region_273     4
# 109              1             Endothelial.Endothelial_s1 15-region_275     4
# 110              1             Endothelial.Endothelial_s1 17-region_279     4
# 111              1             Endothelial.Endothelial_s1 20-region_282     4
# 112              1             Endothelial.Endothelial_s1 19-region_285     2
# 113              1             Endothelial.Endothelial_s1 21-region_287     3
# 114              1             Endothelial.Endothelial_s1 MT-region_288     1
# 115              1                 MastCells.MastCells_s1  1-region_290     4
# 116              1                 MastCells.MastCells_s1  1-region_292     4
# 117              1                 MastCells.MastCells_s1  2-region_294     3
# 118              1                 MastCells.MastCells_s1  5-region_299     4
# 119              1                 MastCells.MastCells_s1  6-region_301     2
# 120              1                 MastCells.MastCells_s1  X-region_305     4
# 121              1                 MastCells.MastCells_s1  8-region_307     4
# 122              1                 MastCells.MastCells_s1 11-region_310     4
# 123              1                 MastCells.MastCells_s1 11-region_312     4
# 124              1                 MastCells.MastCells_s1 12-region_315     4
# 125              1                 MastCells.MastCells_s1 13-region_317     4
# 126              1                 MastCells.MastCells_s1 14-region_319     4
# 127              1             PlasmaCells.PlasmaCells_s1  1-region_333     2
# 128              1             PlasmaCells.PlasmaCells_s1  3-region_337     4
# 129              1             PlasmaCells.PlasmaCells_s1  X-region_344     3
# 130              1             PlasmaCells.PlasmaCells_s1 13-region_350     2
# 131              1             PlasmaCells.PlasmaCells_s1 14-region_352     4
# 132              1             PlasmaCells.PlasmaCells_s1 14-region_353     5
# 133              1             PlasmaCells.PlasmaCells_s1 14-region_354     6
# 134              1             PlasmaCells.PlasmaCells_s1 15-region_356     4
# 230              2             Fibroblasts.Fibroblasts_s1 21-region_204     5
# 231              2             Fibroblasts.Fibroblasts_s1 MT-region_205     1
# 232              2             Endothelial.Endothelial_s1  1-region_207     4
# 233              2             Endothelial.Endothelial_s1  4-region_212     4
# 234              2             Endothelial.Endothelial_s1  6-region_216     2
# 235              2             Endothelial.Endothelial_s1  7-region_219     4
# 236              2             Endothelial.Endothelial_s1  8-region_222     4
# 237              2             Endothelial.Endothelial_s1  9-region_225     3
# 238              2             Endothelial.Endothelial_s1 11-region_226     5
# 239              2             Endothelial.Endothelial_s1 11-region_227     4
# 240              2             Endothelial.Endothelial_s1 10-region_230     3
# 241              2             Endothelial.Endothelial_s1 12-region_232     3
# 242              2             Endothelial.Endothelial_s1 15-region_236     4
# 243              2             Endothelial.Endothelial_s1 17-region_240     4
# 244              2             Endothelial.Endothelial_s1 20-region_243     4
# 245              2             Endothelial.Endothelial_s1 19-region_246     2
# 246              2             Endothelial.Endothelial_s1 21-region_248     3
# 247              2             Endothelial.Endothelial_s1 MT-region_249     1
# 248              2                     Unknown.Unknown_s1  1-region_251     2
# 249              2                     Unknown.Unknown_s1  2-region_253     3
# 250              2                     Unknown.Unknown_s1  5-region_258     4
# 251              2                     Unknown.Unknown_s1  6-region_261     2
# 252              2                     Unknown.Unknown_s1  9-region_266     3
# 253              2                     Unknown.Unknown_s1 11-region_268     4
# 254              2                     Unknown.Unknown_s1 11-region_270     4
# 255              2                     Unknown.Unknown_s1 11-region_271     5
# 256              2                     Unknown.Unknown_s1 10-region_273     4
# 257              2                     Unknown.Unknown_s1 12-region_275     4
# 258              2                     Unknown.Unknown_s1 14-region_279     2
# 259              2                     Unknown.Unknown_s1 16-region_282     4
# 260              2                     Unknown.Unknown_s1 17-region_285     4
# 261              2                     Unknown.Unknown_s1 20-region_289     4
# 262              2                     Unknown.Unknown_s1 19-region_292     4
# 263              2                     Unknown.Unknown_s1 21-region_295     3
# 264              2             PlasmaCells.PlasmaCells_s1  1-region_298     2
# 265              2             PlasmaCells.PlasmaCells_s1  3-region_302     4
# 266              2             PlasmaCells.PlasmaCells_s1  4-region_305     4
# 267              2             PlasmaCells.PlasmaCells_s1  5-region_307     4
# 268              2             PlasmaCells.PlasmaCells_s1  X-region_312     4
# 269              2             PlasmaCells.PlasmaCells_s1 13-region_318     2
# 270              2             PlasmaCells.PlasmaCells_s1 14-region_321     4
# 271              2             PlasmaCells.PlasmaCells_s1 14-region_322     5
# 272              2             PlasmaCells.PlasmaCells_s1 14-region_323     6
# 273              2             PlasmaCells.PlasmaCells_s1 18-region_328     4
# 274              2             PlasmaCells.PlasmaCells_s1 20-region_329     4
# 275              2             PlasmaCells.PlasmaCells_s1 22-region_332     5
# 276              2             PlasmaCells.PlasmaCells_s1 22-region_333     4
# 277              2                 MastCells.MastCells_s1  1-region_338     4
# 278              2                 MastCells.MastCells_s1  1-region_340     4
# 279              2                 MastCells.MastCells_s1  2-region_342     4
# 280              2                 MastCells.MastCells_s1  3-region_345     3
# 281              2                 MastCells.MastCells_s1  5-region_349     3
# 282              2                 MastCells.MastCells_s1  5-region_350     6
# 283              2                 MastCells.MastCells_s1  X-region_353     4
# 284              2                 MastCells.MastCells_s1  8-region_354     3
# 285              2                 MastCells.MastCells_s1 11-region_358     4
# 286              2                 MastCells.MastCells_s1 12-region_361     3
# 287              2                 MastCells.MastCells_s1 13-region_363     4
# 288              2                 MastCells.MastCells_s1 16-region_367     2
# 289              2                 MastCells.MastCells_s1 19-region_372     4
# 290              2                 MastCells.MastCells_s1 MT-region_376     6
# 291              2                       TCells.TCells_s1 MT-region_400     6
# 292              2                     B Cells.B Cells_s1 MT-region_424     6
# 293              3               Epithelial.Epithelial_s1    1-region_2     2
# 294              3               Epithelial.Epithelial_s1    1-region_4     4
# 295              3               Epithelial.Epithelial_s1    1-region_6     3
# 296              3               Epithelial.Epithelial_s1   6-region_12     2
# 297              3               Epithelial.Epithelial_s1   7-region_14     4
# 298              3               Epithelial.Epithelial_s1   8-region_18     3
# 299              3               Epithelial.Epithelial_s1  11-region_21     4
# 300              3               Epithelial.Epithelial_s1  11-region_23     2
# 301              3               Epithelial.Epithelial_s1  12-region_26     4
# 302              3               Epithelial.Epithelial_s1  12-region_28     2
# 303              3               Epithelial.Epithelial_s1  13-region_30     2
# 304              3               Epithelial.Epithelial_s1  16-region_33     3
# 305              3               Epithelial.Epithelial_s1  16-region_35     2
# 306              3               Epithelial.Epithelial_s1  20-region_39     4
# 307              3               Epithelial.Epithelial_s1  19-region_40     3
# 308              3               Epithelial.Epithelial_s1  22-region_42     3
# 309              3               Epithelial.Epithelial_s1  21-region_44     4
# 310              3 CyclingEpithelial.CyclingEpithelial_s1   1-region_47     4
# 311              3 CyclingEpithelial.CyclingEpithelial_s1   1-region_49     3
# 312              3 CyclingEpithelial.CyclingEpithelial_s1   6-region_55     2
# 313              3 CyclingEpithelial.CyclingEpithelial_s1   7-region_57     4
# 314              3 CyclingEpithelial.CyclingEpithelial_s1   8-region_61     3
# 315              3 CyclingEpithelial.CyclingEpithelial_s1  11-region_64     4
# 316              3 CyclingEpithelial.CyclingEpithelial_s1  11-region_66     2
# 317              3 CyclingEpithelial.CyclingEpithelial_s1  12-region_69     4
# 318              3 CyclingEpithelial.CyclingEpithelial_s1  12-region_70     4
# 319              3 CyclingEpithelial.CyclingEpithelial_s1  12-region_71     3
# 320              3 CyclingEpithelial.CyclingEpithelial_s1  12-region_73     3
# 321              3 CyclingEpithelial.CyclingEpithelial_s1  13-region_74     1
# 322              3 CyclingEpithelial.CyclingEpithelial_s1  14-region_76     4
# 323              3 CyclingEpithelial.CyclingEpithelial_s1  16-region_78     4
# 324              3 CyclingEpithelial.CyclingEpithelial_s1  17-region_81     2
# 325              3 CyclingEpithelial.CyclingEpithelial_s1  20-region_85     4
# 326              3 CyclingEpithelial.CyclingEpithelial_s1  20-region_86     3
# 327              3 CyclingEpithelial.CyclingEpithelial_s1  19-region_87     3
# 328              3 CyclingEpithelial.CyclingEpithelial_s1  19-region_89     3
# 329              3 CyclingEpithelial.CyclingEpithelial_s1  22-region_91     4
# 330              3 CyclingEpithelial.CyclingEpithelial_s1  21-region_93     4
# 331              3 CyclingEpithelial.CyclingEpithelial_s1  MT-region_94     6
# 332              3             Endothelial.Endothelial_s1   1-region_96     3
# 333              3             Endothelial.Endothelial_s1  4-region_101     3
# 334              3             Endothelial.Endothelial_s1  6-region_105     2
# 335              3             Endothelial.Endothelial_s1  9-region_111     3
# 336              3             Endothelial.Endothelial_s1 11-region_112     4
# 337              3             Endothelial.Endothelial_s1 12-region_115     3
# 338              3             Endothelial.Endothelial_s1 15-region_119     4
# 339              3             Endothelial.Endothelial_s1 20-region_124     4
# 340              3             Endothelial.Endothelial_s1 19-region_127     2
# 341              3             Endothelial.Endothelial_s1 21-region_129     3
# 342              3             Endothelial.Endothelial_s1 MT-region_130     6
# 343              3             Fibroblasts.Fibroblasts_s1  2-region_135     2
# 344              3             Fibroblasts.Fibroblasts_s1  2-region_137     3
# 345              3             Fibroblasts.Fibroblasts_s1  4-region_141     3
# 346              3             Fibroblasts.Fibroblasts_s1  6-region_144     2
# 347              3             Fibroblasts.Fibroblasts_s1  7-region_147     4
# 348              3             Fibroblasts.Fibroblasts_s1 11-region_151     3
# 349              3             Fibroblasts.Fibroblasts_s1 11-region_153     3
# 350              3             Fibroblasts.Fibroblasts_s1 15-region_158     3
# 351              3             Fibroblasts.Fibroblasts_s1 16-region_161     2
# 352              3             Fibroblasts.Fibroblasts_s1 17-region_163     4
# 353              3             Fibroblasts.Fibroblasts_s1 20-region_167     4
# 354              3             Fibroblasts.Fibroblasts_s1 22-region_171     4
# 355              3             Fibroblasts.Fibroblasts_s1 21-region_173     3
# 356              3             Fibroblasts.Fibroblasts_s1 21-region_174     5
# 357              3             Fibroblasts.Fibroblasts_s1 MT-region_175     6
# 358              3                     Myeloid.Myeloid_s1  1-region_177     4
# 359              3                     Myeloid.Myeloid_s1  6-region_184     3
# 360              3                     Myeloid.Myeloid_s1  7-region_186     3
# 361              3                     Myeloid.Myeloid_s1  8-region_189     3
# 362              3                     Myeloid.Myeloid_s1 11-region_192     3
# 363              3                     Myeloid.Myeloid_s1 11-region_194     4
# 364              3                     Myeloid.Myeloid_s1 14-region_200     3
# 365              3                     Myeloid.Myeloid_s1 15-region_202     3
# 366              3                     Myeloid.Myeloid_s1 20-region_207     4
# 367              3                     Myeloid.Myeloid_s1 19-region_210     4
# 368              3                     Myeloid.Myeloid_s1 22-region_212     3
# 369              3                     Myeloid.Myeloid_s1 21-region_215     3
# 370              3                     Myeloid.Myeloid_s1 MT-region_216     6
# 371              3             PlasmaCells.PlasmaCells_s1  1-region_218     2
# 372              3             PlasmaCells.PlasmaCells_s1  3-region_222     4
# 373              3             PlasmaCells.PlasmaCells_s1 13-region_234     2
# 374              3             PlasmaCells.PlasmaCells_s1 14-region_237     4
# 375              3             PlasmaCells.PlasmaCells_s1 14-region_238     5
# 376              3             PlasmaCells.PlasmaCells_s1 14-region_239     6
# 377              3             PlasmaCells.PlasmaCells_s1 18-region_244     3
# 378              3             PlasmaCells.PlasmaCells_s1 22-region_249     4
# 5                  1               Epithelial.Epithelial_s1       1-region_2
# 6                  1               Epithelial.Epithelial_s1       1-region_2
# 7                  1               Epithelial.Epithelial_s1       1-region_2
# 8                  1               Epithelial.Epithelial_s1       1-region_2
# 9                  1               Epithelial.Epithelial_s1       1-region_2
# 10                 1               Epithelial.Epithelial_s1       1-region_2
# 11                 1               Epithelial.Epithelial_s1       1-region_2
# 12                 1               Epithelial.Epithelial_s1       1-region_2
# 13                 1               Epithelial.Epithelial_s1       1-region_2
# 14                 1               Epithelial.Epithelial_s1       1-region_2
# 15                 1               Epithelial.Epithelial_s1       1-region_2
# 16                 1               Epithelial.Epithelial_s1       1-region_2
# 17                 1               Epithelial.Epithelial_s1       1-region_2
# 18                 1               Epithelial.Epithelial_s1       1-region_2
# 19                 1               Epithelial.Epithelial_s1       1-region_2
# 20                 1               Epithelial.Epithelial_s1       1-region_2
# 21                 1               Epithelial.Epithelial_s1       1-region_2
# 22                 1               Epithelial.Epithelial_s1       1-region_2
# 23                 1               Epithelial.Epithelial_s1       1-region_2
# 24                 1               Epithelial.Epithelial_s1       1-region_2
# 25                 1               Epithelial.Epithelial_s1       1-region_2
# 26                 1               Epithelial.Epithelial_s1       1-region_2
# 27                 1               Epithelial.Epithelial_s1       1-region_2
# 28                 1               Epithelial.Epithelial_s1       1-region_2
# 29                 1               Epithelial.Epithelial_s1       1-region_2
# 30                 1               Epithelial.Epithelial_s1       1-region_2
# 31                 1               Epithelial.Epithelial_s1       1-region_2
# 32                 1               Epithelial.Epithelial_s1       1-region_2
# 33                 1               Epithelial.Epithelial_s1       1-region_2
# 34                 1               Epithelial.Epithelial_s1       1-region_2
# 35                 1               Epithelial.Epithelial_s1       1-region_2
# 36                 1               Epithelial.Epithelial_s1       1-region_2
# 37                 1               Epithelial.Epithelial_s1       1-region_2
# 38                 1               Epithelial.Epithelial_s1       1-region_2
# 39                 1               Epithelial.Epithelial_s1       1-region_2
# 40                 1               Epithelial.Epithelial_s1       1-region_2
# 41                 1               Epithelial.Epithelial_s1       1-region_2
# 42                 1               Epithelial.Epithelial_s1       1-region_2
# 43                 1               Epithelial.Epithelial_s1       1-region_2
# 44                 1               Epithelial.Epithelial_s1       1-region_2
# 45                 1               Epithelial.Epithelial_s1       1-region_2
# 46                 1               Epithelial.Epithelial_s1       1-region_4
# 47                 1               Epithelial.Epithelial_s1       1-region_4
# 48                 1               Epithelial.Epithelial_s1       1-region_4
# 49                 1               Epithelial.Epithelial_s1       1-region_4
# 50                 1               Epithelial.Epithelial_s1       1-region_4
# 51                 1               Epithelial.Epithelial_s1       1-region_4
# 52                 1               Epithelial.Epithelial_s1       1-region_4
# 53                 1               Epithelial.Epithelial_s1       1-region_4
# 54                 1               Epithelial.Epithelial_s1       1-region_4
# 55                 1               Epithelial.Epithelial_s1       1-region_4
# 56                 1               Epithelial.Epithelial_s1       1-region_4
# 57                 1               Epithelial.Epithelial_s1       1-region_4
# 58                 1               Epithelial.Epithelial_s1       1-region_4
# 59                 1               Epithelial.Epithelial_s1       1-region_4
# 60                 1               Epithelial.Epithelial_s1       1-region_4
# 61                 1               Epithelial.Epithelial_s1       1-region_4
# 62                 1               Epithelial.Epithelial_s1       1-region_4
# 63                 1               Epithelial.Epithelial_s1       1-region_4
# 64                 1               Epithelial.Epithelial_s1       1-region_4
# 65                 1               Epithelial.Epithelial_s1       1-region_4
# 66                 1               Epithelial.Epithelial_s1       1-region_4
# 67                 1               Epithelial.Epithelial_s1       1-region_4
# 68                 1               Epithelial.Epithelial_s1       1-region_4
# 69                 1               Epithelial.Epithelial_s1       1-region_4
# 70                 1               Epithelial.Epithelial_s1       1-region_4
# 71                 1               Epithelial.Epithelial_s1       1-region_4
# 72                 1               Epithelial.Epithelial_s1       1-region_4
# ...
# 12175     4         MTPN   7 135926761 135977353
# 12176     4          PTN   7 137227341 137343865
# 12177     4      CREB3L2   7 137874979 138002067
# 12178     4       TRIM24   7 138460334 138589993
# 12179     4      ZC3HAV1   7 139043520 139109719
# 12180     4         UBN2   7 139230356 139308236
# 12181     4         FMC1   7 139339457 139346319
# 12182     4       LUC7L2   7 139340359 139423457
# 12183     4        HIPK2   7 139561570 139777778
# 12184     4        MKRN1   7 140453040 140479569
# 12185     4       NDUFB2   7 140690777 140722790
# 12186     4         BRAF   7 140719327 140924928
# 12187     4       MRPS33   7 141002610 141015228
# 12188     4        SSBP1   7 141738321 141787922
# 12189     4        TRBC2   7 142801041 142802748
# 12190     4          PIP   7 143132077 143139746
# 12191     4        GSTK1   7 143244093 143270854
# 12192     4        CASP2   7 143288215 143307696
# 12193     4          ZYX   7 143381080 143391111
# 12194     4        TCAF1   7 143851375 143902198
# 12195     4     ARHGEF35   7 144186083 144195655
# 12196     4         CUL1   7 148697914 148801036
# 12197     4         EZH2   7 148807383 148884321
# 12198     4        PDIA4   7 149003062 149028641
# 12199     4     ATP6V0E2   7 149872968 149880698
# 12200     4      RARRES2   7 150338317 150341674
# 12201     4       REPIN1   7 150368189 150374044
# 12202     4     TMEM176B   7 150791285 150801360
# 12203     4     TMEM176A   7 150800403 150805120
# 12204     4         CDK5   7 151053812 151058530
# 12205     4       SLC4A2   7 151057210 151076527
# 12206     4        FASTK   7 151076593 151080866
# 12207     4        TMUB1   7 151081080 151083546
# 12208     4         NUB1   7 151341699 151378449
# 12209     4         RHEB   7 151466012 151520120
# 12210     4       PRKAG2   7 151556111 151877125
# 12211     4      GALNT11   7 152025674 152122347
# 12212     4        KMT2C   7 152134922 152436005
# 12213     4       INSIG1   7 155297776 155310235
# 12214     4    LINC01006   7 156472196 156640654
# 12215     4        LMBR1   7 156668946 156893230
# 12216     4         NOM1   7 156949723 156973182
# 12217     4        UBE3C   7 157138913 157269372
# 12218     4       DNAJB6   7 157335381 157417439
# 12219     4        ESYT2   7 158730995 158830253
# 12220     4        WDR60   7 158856578 158956747
# 12221     4        RIC8A  11    207511    215113
# 12222     4       PSMD13  11    236546    252984
# 12223     4        PGGHG  11    289135    296107
# 12224     4       IFITM2  11    307631    315272
# 12225     4       IFITM1  11    313506    315272
# 12226     4       IFITM3  11    319669    327537
# 12499     2       CLEC3A  16  78022515  78066761
#  [ reached 'max' / getOption("max.print") -- omitted 8994 rows ]

# %%
# 4) Summaries for CNV regions and CNV genes
summarize_cnv_regions <- function(merged_regions) {
  # Summarize by chromosome, start, end, and HMM state
  region_summary <- merged_regions %>%
    group_by(chr, start, end, state) %>%
    summarise(
      num_cells = n_distinct(cell_group_name),
      runs_found_in = n_distinct(partial_run_id),
      .groups = "drop"
    )
  return(region_summary)
}

summarize_cnv_genes <- function(merged_genes) {
  # Summarize by gene and CNV state
  gene_summary <- merged_genes %>%
    group_by(gene, state) %>%
    summarise(
      num_cells = n_distinct(cell_group_name),
      runs_found_in = n_distinct(partial_run_id),
      .groups = "drop"
    ) %>%
    arrange(desc(num_cells))
  
  return(gene_summary)
}

# %%
# 3) Function to classify cells as Malignant vs Benign based on merged region calls
#    - For example: if a cell has any called CNV in the merged data, label as Malignant
classify_cells <- function(merged_regions, expression_matrix = NULL) {
  
  # Identify all cells with at least one CNV call
  # Adjust logic or thresholds to define "substantial" CNVs
  cells_with_cnv <- unique(merged_regions$cell_group_name)
  
  # If you have a unified expression matrix, use its column names as total cell set
  # Otherwise, you might have a separate metadata file containing all cell IDs.
  if (!is.null(expression_matrix)) {
    all_cells <- colnames(expression_matrix)
  } else {
    all_cells <- unique(merged_regions$cell_group_name)
  }
  
  classification <- data.frame(cell_id = all_cells, stringsAsFactors = FALSE) %>%
    mutate(Status = ifelse(cell_id %in% cells_with_cnv, "Malignant", "Benign"))
  
  return(classification)
}

# %%
#############################################################################
# Load Required Libraries
#############################################################################
# library(infercnv)
library(dplyr)

# %%
readRDS("/home/igarzonalva/Proyecto_SC_TNBC/GSE161529/InferCNV/split_1/20_HMM_pred.repr_intensitiesHMMi6.hmm_mode-samples.Pnorm_0.5.infercnv_obj")
# Out:
# Loading required package: infercnv
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘infercnv’”
# ERROR while rich displaying an object: Error in .requirePackage(package): unable to find required package ‘infercnv’
#
# Traceback:
# 1. sapply(x, f, simplify = simplify)
# 2. lapply(X = X, FUN = FUN, ...)
# 3. FUN(X[[i]], ...)
# 4. tryCatch(withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler), error = outer_handler)
# 5. tryCatchList(expr, classes, parentenv, handlers)
# 6. tryCatchOne(expr, names, parentenv, handlers[[1L]])
# 7. doTryCatch(return(expr), name, parentenv, handler)
# 8. withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler)
# 9. repr::mime2repr[[mime]](obj)
# 10. .extendsForS3(structure("infercnv", package = "infercnv"))
# 11. extends(Class, maybe = FALSE)
# 12. getClassDef(class1)
# 13. .requirePackage(package)
# 14. stop(gettextf("unable to find required package %s", sQuote(package)),
#   .     domain = NA)

# %%
pred_regions <- read.table(
  "/home/igarzonalva/Proyecto_SC_TNBC/Proyecto_SC_TNBC/GSE161529/InferCNV/split_1/19_HMM_pred.Bayes_NetHMMi6.hmm_mode-samples.Pnorm_0.5.infercnv_obj",
  sep = "\t", header = TRUE, stringsAsFactors = FALSE
)
# Out:
# Warning message in file(file, "rt"):
# “cannot open file '/home/igarzonalva/Proyecto_SC_TNBC/Proyecto_SC_TNBC/GSE161529/InferCNV/split_1/19_HMM_pred.Bayes_NetHMMi6.hmm_mode-samples.Pnorm_0.5.infercnv_obj': No such file or directory”
# Error in file(file, "rt"): cannot open the connection
# Traceback:
#
# 1. file(file, "rt")
# 2. .handleSimpleError(function (cnd)
#  . {
#  .     watcher$capture_plot_and_output()
#  .     cnd <- sanitize_call(cnd)
#  .     watcher$push(cnd)
#  .     switch(on_error, continue = invokeRestart("eval_continue"),
#  .         stop = invokeRestart("eval_stop"), error = invokeRestart("eval_error",
#  .             cnd))
#  . }, "cannot open the connection", base::quote(file(file, "rt")))

# %%
#############################################################################
# 1. Load the Final InferCNV Object (or any key objects you want to inspect)
#############################################################################
# Contains the post-processed expression data and CNV calls.
final_infercnv_obj <- readRDS("run.final.infercnv_obj")

#############################################################################
# 2. Identify Malignant vs. Benign Cells
#############################################################################
# We'll use the HMM-based region calls. If a cell has significant CNV calls
# (amplifications/deletions) in the predicted CNV regions file, we'll
# classify it as "malignant"; otherwise "benign."

# Read the predicted CNV regions file
pred_regions <- read.table(
  "GSE161529/InferCNV/split_1/19_HMM_pred.Bayes_NetHMMi6.hmm_mode-samples.Pnorm_0.5.infercnv_obj",
  sep = "\t", header = TRUE, stringsAsFactors = FALSE
)

# Extract all cell IDs having CNVs (substantial deviations from normal)
cells_with_cnv <- unique(pred_regions$cell_group_name)

# Prepare a data frame with all cell IDs from final_infercnv_obj
all_cells <- data.frame(cell_id = rownames(final_infercnv_obj@expr.data))

# Classify: if a cell is in 'cells_with_cnv', label as "Malignant", else "Benign"
cell_classification <- all_cells %>%
  mutate(Status = ifelse(cell_id %in% cells_with_cnv, "Malignant", "Benign"))

#############################################################################
# 3. Identify Which Regions Have CNVs
#############################################################################
# The pred_regions file shows chromosome, start, end, and predicted CNV state.
# You can filter or group these data to see which regions are most recurrent.

cnv_regions_summary <- pred_regions %>%
  group_by(chr, start, end, state) %>%
  summarise(
    num_cells = n_distinct(cell_group_name),
    .groups = "drop"
  )

# This 'cnv_regions_summary' table indicates how many cells share each CNV.

#############################################################################
# 4. Identify Which Genes Are Implicated in Those CNVs
#############################################################################
# Read the predicted CNV genes file, which includes gene-level calls.
pred_genes <- read.table(
  "HMM_CNV_predictions.HMMi6.hmm_mode-samples.Pnorm_0.5.pred_cnv_genes.dat",
  sep = "\t", header = TRUE, stringsAsFactors = FALSE
)

# Summarize the implicated genes and how many cells show a CNV in each gene
cnv_genes_summary <- pred_genes %>%
  group_by(gene, state) %>%
  summarise(
    num_cells = n_distinct(cell_group_name),
    .groups = "drop"
  ) %>%
  arrange(desc(num_cells))

#############################################################################
# 5. (Optional) Inspect Posterior Probabilities or BayesNet Outputs
#############################################################################
# For deeper inspection or validation, you can load the MCMC or Bayes Net objects:
# mcmc_obj <- readRDS("MCMC_inferCNV_obj.rds")  # Example
# bayes_net_dir <- "BayesNetOutput.HMMi6.hmm_mode-samples"  # Directory with BayesNet results
# ... and use them if needed.

#############################################################################
# 6. Create Publication-Ready Tables or Summaries
#############################################################################
# a) Table of malignant vs benign cells:
head(cell_classification)

# b) Table of major CNV regions:
head(cnv_regions_summary)

# c) Table of top implicated genes:
head(cnv_genes_summary)

#############################################################################
# 7. Save Outputs as CSV (Adjust filenames as needed)
#############################################################################
write.csv(cell_classification,      "cell_classification.csv",     row.names = FALSE)
write.csv(cnv_regions_summary,      "cnv_regions_summary.csv",     row.names = FALSE)
write.csv(cnv_genes_summary,        "cnv_genes_summary.csv",       row.names = FALSE)
