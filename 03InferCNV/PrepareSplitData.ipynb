# %%
import scanpy as sc
import os
import pandas as pd
import numpy as np

# %%
data_dir = "/home/igarzonalva/Proyecto_SC_TNBC/GSE161529/Integration/adata"

# %%
adata = sc.read_h5ad(os.path.join(data_dir,"adata_GenAnno.h5ad"))

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 152319 × 18088
#     obs: 'sample', 'n_genes_by_counts', 'total_counts', 'pct_counts_in_top_50_genes', 'pct_counts_in_top_100_genes', 'pct_counts_in_top_200_genes', 'pct_counts_in_top_500_genes', 'total_counts_mt', 'pct_counts_mt', 'complexity', 'doublet_scores', 'predicted_doublets', 'n_genes', 'n_counts', 'celltypist_labels_Immune_All_High', 'celltypist_scores_Immune_All_High', 'celltypist_labels_Cells_Adult_Breast', 'celltypist_scores_Cells_Adult_Breast', 'batch', 'subtype', 'leiden', 'GenAnno'
#     var: 'highly_variable', 'highly_variable_rank', 'means', 'variances', 'variances_norm', 'highly_variable_nbatches'
#     uns: 'hvg', 'leiden', 'leiden_colors', 'log1p', 'neighbors', 'pca'
#     obsm: 'X_pca', 'X_pca_MDE', 'X_scVI', 'X_scvi_MDE'
#     varm: 'PCs'
#     layers: 'counts'
#     obsp: 'connectivities', 'distances'

# %%
adata.obs
# Out:
#                              sample  n_genes_by_counts  total_counts  \
# AAACCTGAGAAACCGC-1-PM0337-  PM0337-                564        1532.0
# AAACCTGAGACCCACC-1-PM0337-  PM0337-                691        1384.0
# AAACCTGCACCTGGTG-1-PM0337-  PM0337-                629        3215.0
# AAACCTGCACTAGTAC-1-PM0337-  PM0337-               4343       27560.0
# AAACCTGCAGGCGATA-1-PM0337-  PM0337-               2978       15273.0
# ...                             ...                ...           ...
# TTTGTCAAGTTAGGTA-1-MH0126-  MH0126-               1155        2592.0
# TTTGTCACACGTGAGA-1-MH0126-  MH0126-               1067        2898.0
# TTTGTCACATCGGAAG-1-MH0126-  MH0126-               3404       14923.0
# TTTGTCATCCCGACTT-1-MH0126-  MH0126-                579        1175.0
# TTTGTCATCCTGTACC-1-MH0126-  MH0126-               4659       26529.0
#
#                             pct_counts_in_top_50_genes  \
# AAACCTGAGAAACCGC-1-PM0337-                   50.130548
# ...

# %%
adata = adata[np.random.permutation(adata.obs_names)]

# %%
adata.obs
# Out:
#                                  sample  n_genes_by_counts  total_counts  \
# TTAGGCATCAGTGCAT-1-MH0135-      MH0135-               1778        5113.0
# TGACAACAGACTAGAT-1-MH0125-      MH0125-               1855        7652.0
# AGAGAATCATGTTACG-1-MH0161-      MH0161-               3087       10866.0
# AGAATAGAGTGGGATC-1-MH0031-      MH0031-                876        2512.0
# GGGAGATAGTTACCCA-1-MH0135-      MH0135-               2360        6396.0
# ...                                 ...                ...           ...
# ACATACGGTAAACCTC-1-MH0025-      MH0025-               1460        4115.0
# CAATTTCAGTACTGGG-1-MH0176-      MH0176-                958        2194.0
# TGGCGCAAGCTACCGC-1-MH0040-      MH0040-               1403        4045.0
# TTAGTCTGTCAACGCC-1-MH0167-T-  MH0167-T-               1621        5129.0
# CTCACACTCAACCATG-1-PM0360-      PM0360-               1304        4570.0
#
#                               pct_counts_in_top_50_genes  \
# ...

# %%
split_size = adata.n_obs // 3
subset1 = adata[:split_size].copy()
subset2 = adata[split_size:2*split_size].copy()
subset3 = adata[2*split_size:].copy()

# %%
subset1
# Out:
# AnnData object with n_obs × n_vars = 50773 × 18088
#     obs: 'sample', 'n_genes_by_counts', 'total_counts', 'pct_counts_in_top_50_genes', 'pct_counts_in_top_100_genes', 'pct_counts_in_top_200_genes', 'pct_counts_in_top_500_genes', 'total_counts_mt', 'pct_counts_mt', 'complexity', 'doublet_scores', 'predicted_doublets', 'n_genes', 'n_counts', 'celltypist_labels_Immune_All_High', 'celltypist_scores_Immune_All_High', 'celltypist_labels_Cells_Adult_Breast', 'celltypist_scores_Cells_Adult_Breast', 'batch', 'subtype', 'leiden', 'GenAnno'
#     var: 'highly_variable', 'highly_variable_rank', 'means', 'variances', 'variances_norm', 'highly_variable_nbatches'
#     uns: 'hvg', 'leiden', 'leiden_colors', 'log1p', 'neighbors', 'pca'
#     obsm: 'X_pca', 'X_pca_MDE', 'X_scVI', 'X_scvi_MDE'
#     varm: 'PCs'
#     layers: 'counts'
#     obsp: 'connectivities', 'distances'

# %%
genes1 = set(subset2.obs_names.values)
genes2 = set(subset3.obs_names.values)
genes1.intersection(genes2)
# Out:
# set()
