# %%
import scProportionTest as pt
import pandas as pd

# %%
resultsERTNBC = pd.read_csv("/home/igarzonalva/Proyecto_SC_TNBC/GSE161529/proportiontest/scPropTest_ER_vs_ref_TNBC_results.csv")

# %%
plot = pt.point_range_plot(resultsERTNBC, figsize=(6,4), fold_difference = 1,alpha = 0.01,ascending = True,plot_title = "ER vs TNBC ")

# %%
resultsHER2TNBC = pd.read_csv("/home/igarzonalva/Proyecto_SC_TNBC/GSE161529/proportiontest/scPropTest_HER2_vs_ref_TNBC_results.csv")

# %%
plot = pt.point_range_plot(resultsHER2TNBC, figsize=(6,4), fold_difference = 1,alpha = 0.01,ascending = True,plot_title = "HER2 vs TNBC ")

# %%
resultsERHER2 = pd.read_csv("/home/igarzonalva/Proyecto_SC_TNBC/GSE161529/proportiontest/scPropTest_ER_vs_ref_HER2_results.csv")

# %%
plot = pt.point_range_plot(resultsERHER2, figsize=(6,4), fold_difference = 1,alpha = 0.01,ascending = True,plot_title = "ER vs HER2 ")
